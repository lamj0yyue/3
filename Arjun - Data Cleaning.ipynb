# %%
import pandas as pd
import numpy as np

# %%
table = pd.read_csv('United_States_COVID-19_County_Level_of_Community_Transmission_Historical_Changes_-_ARCHIVED-2.csv')

# %%
table
# Out:
#            state_name        county_name  fips_code        date  \
# 0               Texas     Jackson County      48239  01/27/2020
# 1            Nebraska     Buffalo County      31019  01/27/2020
# 2            Illinois       Coles County      17029  01/27/2020
# 3                Iowa         Ida County      19093  01/27/2020
# 4           Tennessee        Knox County      47093  02/05/2020
# ...               ...                ...        ...         ...
# 3225217     Louisiana  Assumption Parish      22007  10/18/2022
# 3225218  South Dakota        Hyde County      46069  10/18/2022
# 3225219         Texas      Loving County      48301  10/18/2022
# 3225220      Virginia     Lynchburg City      51680  10/18/2022
# 3225221       Wyoming    Converse County      56009  10/18/2022
#
#         cases_per_100K_7_day_count_change  \
# 0                                   0.000
# 1                                   0.000
# 2                                   0.000
# ...

# %%
result = table.loc[table['county_name'] == 'Alameda County']
result
# Out:
#          state_name     county_name  fips_code        date  \
# 702      California  Alameda County       6001  10/17/2022
# 5111     California  Alameda County       6001  01/26/2020
# 10048    California  Alameda County       6001  01/31/2020
# 12269    California  Alameda County       6001  02/13/2020
# 14712    California  Alameda County       6001  02/14/2020
# ...             ...             ...        ...         ...
# 3211034  California  Alameda County       6001  06/21/2022
# 3213893  California  Alameda County       6001  08/31/2022
# 3215956  California  Alameda County       6001  09/13/2022
# 3220671  California  Alameda County       6001  10/02/2022
# 3224185  California  Alameda County       6001  10/18/2022
#
#         cases_per_100K_7_day_count_change  \
# 702                                61.628
# 5111                                0.000
# 10048                               0.000
# 12269                               0.000
# ...

# %%
vals = result.dtypes
vals
# Out:
# state_name                                             object
# county_name                                            object
# fips_code                                               int64
# date                                                   object
# cases_per_100K_7_day_count_change                      object
# percent_test_results_reported_positive_last_7_days    float64
# community_transmission_level                           object
# dtype: object

# %%
result['date']= pd.to_datetime(result['date'])
# Out:
# /var/folders/8w/62gl8b6s47j_74207j1mns0r0000gn/T/ipykernel_25656/1564211628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['date']= pd.to_datetime(result['date'])

# %%
result
# Out:
#          state_name     county_name  fips_code       date  \
# 702      California  Alameda County       6001 2022-10-17
# 5111     California  Alameda County       6001 2020-01-26
# 10048    California  Alameda County       6001 2020-01-31
# 12269    California  Alameda County       6001 2020-02-13
# 14712    California  Alameda County       6001 2020-02-14
# ...             ...             ...        ...        ...
# 3211034  California  Alameda County       6001 2022-06-21
# 3213893  California  Alameda County       6001 2022-08-31
# 3215956  California  Alameda County       6001 2022-09-13
# 3220671  California  Alameda County       6001 2022-10-02
# 3224185  California  Alameda County       6001 2022-10-18
#
#         cases_per_100K_7_day_count_change  \
# 702                                61.628
# 5111                                0.000
# 10048                               0.000
# 12269                               0.000
# 14712                               0.000
# ...

# %%
vals = result.dtypes
vals
# Out:
# state_name                                                    object
# county_name                                                   object
# fips_code                                                      int64
# date                                                  datetime64[ns]
# cases_per_100K_7_day_count_change                             object
# percent_test_results_reported_positive_last_7_days           float64
# community_transmission_level                                  object
# dtype: object

# %%
result.sort_values(by='date', inplace = True)
result
# Out:
# /var/folders/8w/62gl8b6s47j_74207j1mns0r0000gn/T/ipykernel_25656/2983493923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result.sort_values(by='date', inplace = True)
#          state_name     county_name  fips_code       date  \
# 2331985  California  Alameda County       6001 2020-01-22
# 1952013  California  Alameda County       6001 2020-01-23
# 1185466  California  Alameda County       6001 2020-01-24
# 2701966  California  Alameda County       6001 2020-01-25
# 5111     California  Alameda County       6001 2020-01-26
# ...             ...             ...        ...        ...
# 2698450  California  Alameda County       6001 2022-10-14
# 1565174  California  Alameda County       6001 2022-10-15
# 1950925  California  Alameda County       6001 2022-10-16
# ...
